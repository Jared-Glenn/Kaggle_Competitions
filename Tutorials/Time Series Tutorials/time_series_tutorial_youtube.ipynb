# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
shampoo = pd.read_csv('Documents/3. Programming/Data Science Practice/Data For Tutorial/shampoo_with_exog.csv')

# %%
type(shampoo)
# Out:
# pandas.core.frame.DataFrame

# %%
shampoo = pd.read_csv('Documents/3. Programming/Data Science Practice/Data For Tutorial/shampoo_with_exog.csv',index_col= [0], parse_dates=True).squeeze("columns")

# %%
type(shampoo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(shampoo)
# Out:
# pandas.core.frame.DataFrame

# %%
shampoo.plot()
# Out:
# <AxesSubplot:xlabel='Month'>
